# %%
import pandas as pd
import os

os.chdir(r"C:\IMS_Mestrado\1oAno_1oSemestre\ProgrammingForDataScience\Projeto\API_ST.INT.ARVL_DS2_en_csv_v2_103871")
importedFile =  pd.read_csv(r"API_ST.INT.ARVL_DS2_en_csv_v2_103871.csv", skiprows=4)
# Out:
#      Country Name Country Code                             Indicator Name  \
# 259        Kosovo          XKX  International tourism, number of arrivals
# 260   Yemen, Rep.          YEM  International tourism, number of arrivals
# 261  South Africa          ZAF  International tourism, number of arrivals
# 262        Zambia          ZMB  International tourism, number of arrivals
# 263      Zimbabwe          ZWE  International tourism, number of arrivals
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 259    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 260    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  1025000.0
# 261    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  8074000.0
# 262    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...   815000.0
# 263    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  2239000.0
#
#           2011       2012       2013       2014       2015        2016  \
# ...
